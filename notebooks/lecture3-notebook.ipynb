# %%
x = 1

if x > 2:
    print("x is bigger than 2")
elif x < 0:
    print("x is negative")
else:
    print("x is 0, 1, or 2")
# Out:
# x is 0, 1, or 2

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
import random

value = random.randint(1000,9999)



if value % 2 == 1:
    print("value is odd")
print("value is ", value)

# %%
evens = 0
odds = 0

# %%
value = random.randint(1000,9999)
if value % 2 == 1:
    print("value is odd")
    odds = odds + 1
else:
    evens += 1
print("value is ", value)
print("odds ", odds)
print("evens ", evens)
# Out:
# value is  9196
# odds  6
# evens  15

# %%
count = 0

while count < 50:
    value = random.randint(1000,9999)
    if value % 2 == 1:
        print("value is odd")
        odds = odds + 1
    else:
        evens += 1
    print("value is ", value)
    print("odds ", odds)
    print("evens ", evens)
    count += 1
    # this is commnet
# Out:
# value is odd
# value is  4857
# odds  40
# evens  32
# value is odd
# value is  6285
# odds  41
# evens  32
# value is  2676
# odds  41
# evens  33
# value is  7326
# odds  41
# evens  34
# value is  5850
# odds  41
# evens  35
# value is odd
# value is  4419
# odds  42
# evens  35
# value is odd
# value is  5685
# odds  43
# evens  35
# value is  2346
# odds  43
# evens  36
# value is odd
# value is  6299
# odds  44
# evens  36
# value is  3962
# odds  44
# evens  37
# value is odd
# value is  5609
# odds  45
# evens  37
# value is  5954
# odds  45
# evens  38
# value is  1940
# odds  45
# evens  39
# value is  3804
# odds  45
# evens  40
# value is  1336
# odds  45
# evens  41
# value is odd
# value is  2863
# odds  46
# evens  41
# value is  9852
# odds  46
# evens  42
# value is odd
# value is  6763
# odds  47
# evens  42
# value is  7174
# odds  47
# evens  43
# value is  3672
# odds  47
# evens  44
# value is odd
# value is  6035
# odds  48
# evens  44
# value is  7426
# odds  48
# evens  45
# value is odd
# value is  6409
# odds  49
# evens  45
# value is  1180
# odds  49
# evens  46
# value is odd
# value is  6821
# odds  50
# evens  46
# value is  1522
# odds  50
# evens  47
# value is  5878
# odds  50
# evens  48
# value is odd
# value is  7977
# odds  51
# evens  48
# value is  3766
# odds  51
# evens  49
# value is  3002
# odds  51
# evens  50
# value is  4158
# odds  51
# evens  51
# value is odd
# value is  4025
# odds  52
# evens  51
# value is odd
# value is  1113
# odds  53
# evens  51
# value is odd
# value is  5477
# odds  54
# evens  51
# value is  4878
# odds  54
# evens  52
# value is odd
# value is  8711
# odds  55
# evens  52
# value is odd
# value is  9649
# odds  56
# evens  52
# value is odd
# value is  5165
# odds  57
# evens  52
# value is  8122
# odds  57
# evens  53
# value is odd
# value is  7891
# odds  58
# evens  53
# value is  9384
# odds  58
# evens  54
# value is odd
# value is  7903
# odds  59
# evens  54
# value is  5362
# odds  59
# evens  55
# value is  4812
# odds  59
# evens  56
# value is  9836
# odds  59
# evens  57
# value is  4598
# odds  59
# evens  58
# value is  7932
# odds  59
# evens  59
# value is odd
# value is  7327
# odds  60
# evens  59
# value is odd
# value is  4689
# odds  61
# evens  59
# value is odd
# value is  3587
# odds  62
# evens  59
